# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import time

def get_date_list(start_date_str, end_date_str):
    start = datetime.strptime(start_date_str, "%Y-%m-%d")
    end = datetime.strptime(end_date_str, "%Y-%m-%d")
    dates = []
    while start <= end:
        dates.append(start.strftime("%Y%m%d"))
        start += timedelta(days=1)
    return dates

def extract_real_chart_date(soup):
    """
    벅스 차트 페이지에 실제로 표시된 날짜 추출
    <time datetime="2025.06.01 12:00"> → "20250601" 반환
    """
    time_tag = soup.select_one("fieldset.filterChart time[datetime]")
    if time_tag:
        datetime_str = time_tag["datetime"]  # 예: 2025.06.01 12:00
        chart_date = datetime.strptime(datetime_str.split()[0], "%Y.%m.%d")
        return chart_date.strftime("%Y%m%d")
    return None

def scrape_bugs_chart(date):
    url = f"https://music.bugs.co.kr/chart/track/day/total?chartdate={date}"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
     # 실제 표시된 날짜 추출
    real_chart_date = extract_real_chart_date(soup)
    if real_chart_date != date:
        print(f"요청한 날짜 {date}와 실제 차트 날짜 {real_chart_date} 불일치 → 중단")
        return None, False

    chart_table = soup.select_one("table.list.trackList.byChart tbody")
    if not chart_table:
        print(f"{date}: 차트 정보 없음")
        return [], True

    results = []
    rows = chart_table.find_all("tr")

    for row in rows:
        try:
            # 순위
            ranking = row.select_one("div.ranking > strong").text.strip()

            # 제목
            title = row.select_one("p.title").get_text(strip=True)

            # 가수
            artist = row.select_one("p.artist").get_text(strip=True)

            results.append({
                "date": date,
                "ranking": ranking,
                "title": title,
                "artist": artist
            })
        except Exception as e:
            # print(f"파싱 오류: {e}")
            continue

    print(f"{date} - {len(results)}곡 수집됨")
    return results, True

def crawl_bugs_range(start_date, end_date, delay_sec=3):
    all_results = []
    dates = get_date_list(start_date, end_date)
    for date in dates:
        print(f"{date} 크롤링 시작")
        day_result, should_continue = scrape_bugs_chart(date)
        if not should_continue:
            print("이후 날짜는 아직 업데이트되지 않음 → 중단")
            break
        all_results.extend(day_result)
        time.sleep(delay_sec)  # 서버 부하 방지

    return all_results

# 예시 실행
start_date = "2025-05-31"
end_date = "2025-06-10"

#날짜 유효성 검사
try:
    datetime.strptime(start_date, "%Y-%m-%d")
    datetime.strptime(end_date, "%Y-%m-%d")
except ValueError as e:
    print(f"날짜 형식 오류 또는 존재하지 않는 날짜입니다: {e}")
    exit(1)  # 이후 코드 실행 중단


data = crawl_bugs_range(start_date, end_date)
# Out:
# 20250531 크롤링 시작
# 20250531 - 100곡 수집됨
# 20250601 크롤링 시작
# 20250601 - 100곡 수집됨
# 20250602 크롤링 시작
# 20250602 - 100곡 수집됨
# 20250603 크롤링 시작
# 요청한 날짜 20250603와 실제 차트 날짜 20250602 불일치 → 중단
# 이후 날짜는 아직 업데이트되지 않음 → 중단

# %%
from collections import defaultdict

def pretty_print_bugs_chart(data):
    # 날짜별로 정리
    chart_by_date = defaultdict(list)
    for row in data:
        chart_by_date[row["date"]].append(row)

    # 날짜 오름차순으로 출력
    for date in sorted(chart_by_date.keys()):
        print(f"\n{date} 일간 차트")
        print("-" * 50)
        # 순위순 정렬
        sorted_chart = sorted(chart_by_date[date], key=lambda x: int(x["ranking"]))
        for r in sorted_chart:
            print(f"#{r['ranking']:>3} | {r['title']} - {r['artist']}")

pretty_print_bugs_chart(data)
# Out:
# 20250531 일간 차트
# --------------------------------------------------
# #  1 | THUNDER - 세븐틴(SEVENTEEN)
# #  2 | Never Ending Story - 아이유(IU)
# #  3 | 너에게 닿기를 - 10CM
# #  4 | Drowning - WOODZ
# #  5 | 네모의 꿈 - 아이유(IU)
# #  6 | like JENNIE - 제니 (JENNIE)
# #  7 | 그날이 오면 - 투모로우바이투게더
# #  8 | HANDS UP - MEOVV (미야오)
# #  9 | Whiplash - aespa
# # 10 | HOT - LE SSERAFIM (르세라핌)
# # 11 | Maybe Tomorrow - DAY6 (데이식스)
# # 12 | 나는 반딧불 - 황가람
# # 13 | REBEL HEART - IVE (아이브)
# # 14 | 모르시나요(PROD.로코베리) - 조째즈
# # 15 | I DO ME - KiiiKiii (키키)
# # 16 | 빨간 운동화 - 아이유(IU)
# # 17 | APT. - 로제(ROSÉ)로제(ROSÉ)
# # 18 | Last Scene (Feat. 원슈타인) - 아이유(IU)
# # 19 | 청춘만화 - 이무진
# # 20 | TOO BAD (feat. Anderson .Paak) - G-DRAGON
# # 21 | Pookie - FIFTY FIFTY
# # 22 | HAPPY - DAY6 (데이식스)
# # 23 | Die With A Smile - Lady GaGa(레이디 가가)Lady GaGa(레이디 가가)
# # 24 | 한 페이지가 될 수 있게 - DAY6 (데이식스)
# # 25 | toxic till the end - 로제(ROSÉ)
# # 26 | 마음 따라 뛰는 건 멋지지 않아? - TWS (투어스)
# # 27 | ATTITUDE - IVE (아이브)
# # 28 | HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# # 29 | 오늘만 I LOVE YOU - BOYNEXTDOOR
# # 30 | Supernova - aespa
# # 31 | 10월 4일 - 아이유(IU)
# # 32 | Welcome to the Show - DAY6 (데이식스)
# # 33 | Fly Up - RIIZE
# # 34 | LOVE ATTACK - RESCENE (리센느)
# # 35 | 고민중독 - QWER
# # 36 | 내 이름 맑음 - QWER
# # 37 | 시작의 아이 - 마크툽(MAKTUB)
# # 38 | Mantra - 제니 (JENNIE)
# # 39 | The Chase - Hearts2Hearts (하츠투하츠)
# # 40 | Flower - 오반(OVAN)
# # 41 | How Sweet - NewJeans
# # 42 | 미인 (Feat. Balming Tiger) - 아이유(IU)
# # 43 | 영원해 - 도경수(D.O.)
# # 44 | 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# # 45 | Magnetic - 아일릿(ILLIT)
# # 46 | 나는 아픈 건 딱 질색이니까 - i-dle (아이들)
# # 47 | 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# # 48 | 예뻤어 - DAY6 (데이식스)
# # 49 | 소나기 - 이클립스 (ECLIPSE)
# # 50 | 천상연 - 이창섭
# # 51 | DRIP - BABYMONSTER
# # 52 | 에피소드 - 이무진
# # 53 | I AM - IVE (아이브)
# # 54 | Supernatural - NewJeans
# # 55 | UP (KARINA Solo) - aespa
# # 56 | Hype Boy - NewJeans
# # 57 | Congratulations - DAY6 (데이식스)
# # 58 | 1999 - 마크 (MARK)
# # 59 | 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU(악뮤)
# # 60 | Sticky - KISS OF LIFE
# # 61 | 미치게 그리워서 - 황가람
# # 62 | 주저하는 연인들을 위해 - 잔나비
# # 63 | Armageddon - aespa
# # 64 | Cruel Summer - Taylor Swift(테일러 스위프트)
# # 65 | Love me or Leave me - DAY6 (데이식스)
# # 66 | Good Thing - i-dle (아이들)
# # 67 | TAKE ME - G-DRAGON
# # 68 | number one girl - 로제(ROSÉ)
# # 69 | 끝났지 - DAY6 (데이식스)
# # 70 | luther - Kendrick Lamar(켄드릭 라마)Kendrick Lamar(켄드릭 라마)
# # 71 | 너와의 모든 지금 - 재쓰비 (JAESSBEE)
# # 72 | 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴(Paul Kim)
# # 73 | 녹아내려요 - DAY6 (데이식스)
# # 74 | PO￦ER - G-DRAGON
# # 75 | Small girl (feat. 도경수(D.O.)) - 이영지
# # 76 | Love wins all - 아이유(IU)
# # 77 | Attention - NewJeans
# # 78 | SIGN - izna (이즈나)
# # 79 | Ditto - NewJeans
# # 80 | 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션(Nerd Connection)
# # 81 | 사랑인가 봐 - 멜로망스(MeloMance)
# # 82 | 밤양갱 - 비비(BIBI)
# # 83 | LOVE DIVE - IVE (아이브)
# # 84 | 만년설 (Everlasting) - 엔플라잉(N.Flying)
# # 85 | ExtraL (feat. Doechii) - 제니 (JENNIE)제니 (JENNIE)
# # 86 | Supersonic - 프로미스나인
# # 87 | 너의 모든 순간 - 성시경
# # 88 | Come Over - LE SSERAFIM (르세라핌)
# # 89 | 청혼하지 않을 이유를 못 찾았어 - 이무진
# # 90 | Bag Bad Back - RIIZE
# # 91 | 무제(無題) (Untitled, 2014) - G-DRAGON
# # 92 | Bubble Gum - NewJeans
# # 93 | After LIKE - IVE (아이브)
# # 94 | Live My Life - aespa
# # 95 | 비의 랩소디 - 임재현
# # 96 | Igloo - KISS OF LIFE
# # 97 | ETA - NewJeans
# # 98 | 슬픈 초대장 - 순순희 (지환)
# # 99 | CHAMPION (Prod. THE HUB) - 성한빈 (ZEROBASEONE)
# #100 | To. X - 태연 (TAEYEON)
#
# 20250601 일간 차트
# --------------------------------------------------
# #  1 | THUNDER - 세븐틴(SEVENTEEN)
# #  2 | Never Ending Story - 아이유(IU)
# #  3 | 너에게 닿기를 - 10CM
# #  4 | 네모의 꿈 - 아이유(IU)
# #  5 | Drowning - WOODZ
# #  6 | like JENNIE - 제니 (JENNIE)
# #  7 | HANDS UP - MEOVV (미야오)
# #  8 | Whiplash - aespa
# #  9 | Maybe Tomorrow - DAY6 (데이식스)
# # 10 | HOT - LE SSERAFIM (르세라핌)
# # 11 | 그날이 오면 - 투모로우바이투게더
# # 12 | REBEL HEART - IVE (아이브)
# # 13 | I DO ME - KiiiKiii (키키)
# # 14 | 모르시나요(PROD.로코베리) - 조째즈
# # 15 | 나는 반딧불 - 황가람
# # 16 | 빨간 운동화 - 아이유(IU)
# # 17 | TOO BAD (feat. Anderson .Paak) - G-DRAGON
# # 18 | HAPPY - DAY6 (데이식스)
# # 19 | 청춘만화 - 이무진
# # 20 | Last Scene (Feat. 원슈타인) - 아이유(IU)
# # 21 | APT. - 로제(ROSÉ)로제(ROSÉ)
# # 22 | Pookie - FIFTY FIFTY
# # 23 | toxic till the end - 로제(ROSÉ)
# # 24 | Die With A Smile - Lady GaGa(레이디 가가)Lady GaGa(레이디 가가)
# # 25 | Fly Up - RIIZE
# # 26 | ATTITUDE - IVE (아이브)
# # 27 | 한 페이지가 될 수 있게 - DAY6 (데이식스)
# # 28 | 마음 따라 뛰는 건 멋지지 않아? - TWS (투어스)
# # 29 | HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# # 30 | 오늘만 I LOVE YOU - BOYNEXTDOOR
# # 31 | Supernova - aespa
# # 32 | 10월 4일 - 아이유(IU)
# # 33 | Welcome to the Show - DAY6 (데이식스)
# # 34 | 시작의 아이 - 마크툽(MAKTUB)
# # 35 | LOVE ATTACK - RESCENE (리센느)
# # 36 | 내 이름 맑음 - QWER
# # 37 | Mantra - 제니 (JENNIE)
# # 38 | 고민중독 - QWER
# # 39 | The Chase - Hearts2Hearts (하츠투하츠)
# # 40 | Flower - 오반(OVAN)
# # 41 | 미인 (Feat. Balming Tiger) - 아이유(IU)
# # 42 | 영원해 - 도경수(D.O.)
# # 43 | 나는 아픈 건 딱 질색이니까 - i-dle (아이들)
# # 44 | 소나기 - 이클립스 (ECLIPSE)
# # 45 | 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# # 46 | Magnetic - 아일릿(ILLIT)
# # 47 | 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# # 48 | 천상연 - 이창섭
# # 49 | How Sweet - NewJeans
# # 50 | 예뻤어 - DAY6 (데이식스)
# # 51 | 에피소드 - 이무진
# # 52 | Supernatural - NewJeans
# # 53 | DRIP - BABYMONSTER
# # 54 | 만년설 (Everlasting) - 엔플라잉(N.Flying)
# # 55 | Congratulations - DAY6 (데이식스)
# # 56 | UP (KARINA Solo) - aespa
# # 57 | I AM - IVE (아이브)
# # 58 | 1999 - 마크 (MARK)
# # 59 | 끝났지 - DAY6 (데이식스)
# # 60 | Good Thing - i-dle (아이들)
# # 61 | 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU(악뮤)
# # 62 | Hype Boy - NewJeans
# # 63 | PO￦ER - G-DRAGON
# # 64 | Armageddon - aespa
# # 65 | 미치게 그리워서 - 황가람
# # 66 | luther - Kendrick Lamar(켄드릭 라마)Kendrick Lamar(켄드릭 라마)
# # 67 | Cruel Summer - Taylor Swift(테일러 스위프트)
# # 68 | 주저하는 연인들을 위해 - 잔나비
# # 69 | Love me or Leave me - DAY6 (데이식스)
# # 70 | Sticky - KISS OF LIFE
# # 71 | number one girl - 로제(ROSÉ)
# # 72 | 너와의 모든 지금 - 재쓰비 (JAESSBEE)
# # 73 | TAKE ME - G-DRAGON
# # 74 | SIGN - izna (이즈나)
# # 75 | Small girl (feat. 도경수(D.O.)) - 이영지
# # 76 | 녹아내려요 - DAY6 (데이식스)
# # 77 | Love wins all - 아이유(IU)
# # 78 | Attention - NewJeans
# # 79 | Supersonic - 프로미스나인
# # 80 | 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴(Paul Kim)
# # 81 | Ditto - NewJeans
# # 82 | 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션(Nerd Connection)
# # 83 | Bag Bad Back - RIIZE
# # 84 | ExtraL (feat. Doechii) - 제니 (JENNIE)제니 (JENNIE)
# # 85 | 밤양갱 - 비비(BIBI)
# # 86 | LOVE DIVE - IVE (아이브)
# # 87 | 사랑인가 봐 - 멜로망스(MeloMance)
# # 88 | 무제(無題) (Untitled, 2014) - G-DRAGON
# # 89 | 청혼하지 않을 이유를 못 찾았어 - 이무진
# # 90 | Come Over - LE SSERAFIM (르세라핌)
# # 91 | 너의 모든 순간 - 성시경
# # 92 | Bubble Gum - NewJeans
# # 93 | After LIKE - IVE (아이브)
# # 94 | Poet | Artist - SHINee (샤이니)
# # 95 | Live My Life - aespa
# # 96 | 비의 랩소디 - 임재현
# # 97 | Igloo - KISS OF LIFE
# # 98 | ETA - NewJeans
# # 99 | CHAMPION (Prod. THE HUB) - 성한빈 (ZEROBASEONE)
# #100 | 사건의 지평선 - 윤하(Younha/ユンナ)
#
# 20250602 일간 차트
# --------------------------------------------------
# #  1 | Never Ending Story - 아이유(IU)
# #  2 | 너에게 닿기를 - 10CM
# #  3 | 네모의 꿈 - 아이유(IU)
# #  4 | Drowning - WOODZ
# #  5 | like JENNIE - 제니 (JENNIE)
# #  6 | HANDS UP - MEOVV (미야오)
# #  7 | Whiplash - aespa
# #  8 | Maybe Tomorrow - DAY6 (데이식스)
# #  9 | HOT - LE SSERAFIM (르세라핌)
# # 10 | 그날이 오면 - 투모로우바이투게더
# # 11 | I DO ME - KiiiKiii (키키)
# # 12 | REBEL HEART - IVE (아이브)
# # 13 | 모르시나요(PROD.로코베리) - 조째즈
# # 14 | 나는 반딧불 - 황가람
# # 15 | Pookie - FIFTY FIFTY
# # 16 | TOO BAD (feat. Anderson .Paak) - G-DRAGON
# # 17 | Last Scene (Feat. 원슈타인) - 아이유(IU)
# # 18 | 빨간 운동화 - 아이유(IU)
# # 19 | HAPPY - DAY6 (데이식스)
# # 20 | 청춘만화 - 이무진
# # 21 | THUNDER - 세븐틴(SEVENTEEN)
# # 22 | APT. - 로제(ROSÉ)로제(ROSÉ)
# # 23 | Die With A Smile - Lady GaGa(레이디 가가)Lady GaGa(레이디 가가)
# # 24 | 마음 따라 뛰는 건 멋지지 않아? - TWS (투어스)
# # 25 | toxic till the end - 로제(ROSÉ)
# # 26 | 한 페이지가 될 수 있게 - DAY6 (데이식스)
# # 27 | HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# # 28 | ATTITUDE - IVE (아이브)
# # 29 | 오늘만 I LOVE YOU - BOYNEXTDOOR
# # 30 | Supernova - aespa
# # 31 | 10월 4일 - 아이유(IU)
# # 32 | 시작의 아이 - 마크툽(MAKTUB)
# # 33 | Fly Up - RIIZE
# # 34 | Mantra - 제니 (JENNIE)
# # 35 | LOVE ATTACK - RESCENE (리센느)
# # 36 | 내 이름 맑음 - QWER
# # 37 | The Chase - Hearts2Hearts (하츠투하츠)
# # 38 | Welcome to the Show - DAY6 (데이식스)
# # 39 | 고민중독 - QWER
# # 40 | Flower - 오반(OVAN)
# # 41 | How Sweet - NewJeans
# # 42 | 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# # 43 | 영원해 - 도경수(D.O.)
# # 44 | Magnetic - 아일릿(ILLIT)
# # 45 | 미인 (Feat. Balming Tiger) - 아이유(IU)
# # 46 | 소나기 - 이클립스 (ECLIPSE)
# # 47 | 첫 만남은 계획대로 되지 않아 - TWS (투어스)
# # 48 | 나는 아픈 건 딱 질색이니까 - i-dle (아이들)
# # 49 | Hype Boy - NewJeans
# # 50 | Supernatural - NewJeans
# # 51 | 에피소드 - 이무진
# # 52 | DRIP - BABYMONSTER
# # 53 | 천상연 - 이창섭
# # 54 | 예뻤어 - DAY6 (데이식스)
# # 55 | SIGN - izna (이즈나)
# # 56 | I AM - IVE (아이브)
# # 57 | Congratulations - DAY6 (데이식스)
# # 58 | Armageddon - aespa
# # 59 | Cruel Summer - Taylor Swift(테일러 스위프트)
# # 60 | Good Thing - i-dle (아이들)
# # 61 | number one girl - 로제(ROSÉ)
# # 62 | UP (KARINA Solo) - aespa
# # 63 | Love me or Leave me - DAY6 (데이식스)
# # 64 | 미치게 그리워서 - 황가람
# # 65 | 1999 - 마크 (MARK)
# # 66 | 만년설 (Everlasting) - 엔플라잉(N.Flying)
# # 67 | TAKE ME - G-DRAGON
# # 68 | Sticky - KISS OF LIFE
# # 69 | 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU(악뮤)
# # 70 | PO￦ER - G-DRAGON
# # 71 | Love wins all - 아이유(IU)
# # 72 | Small girl (feat. 도경수(D.O.)) - 이영지
# # 73 | 주저하는 연인들을 위해 - 잔나비
# # 74 | 밤양갱 - 비비(BIBI)
# # 75 | luther - Kendrick Lamar(켄드릭 라마)Kendrick Lamar(켄드릭 라마)
# # 76 | 너와의 모든 지금 - 재쓰비 (JAESSBEE)
# # 77 | Attention - NewJeans
# # 78 | 녹아내려요 - DAY6 (데이식스)
# # 79 | 끝났지 - DAY6 (데이식스)
# # 80 | 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴(Paul Kim)
# # 81 | Ditto - NewJeans
# # 82 | ExtraL (feat. Doechii) - 제니 (JENNIE)제니 (JENNIE)
# # 83 | 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션(Nerd Connection)
# # 84 | Supersonic - 프로미스나인
# # 85 | 청혼하지 않을 이유를 못 찾았어 - 이무진
# # 86 | 사랑인가 봐 - 멜로망스(MeloMance)
# # 87 | LOVE DIVE - IVE (아이브)
# # 88 | Come Over - LE SSERAFIM (르세라핌)
# # 89 | After LIKE - IVE (아이브)
# # 90 | Bag Bad Back - RIIZE
# # 91 | 너의 모든 순간 - 성시경
# # 92 | Bubble Gum - NewJeans
# # 93 | 무제(無題) (Untitled, 2014) - G-DRAGON
# # 94 | Live My Life - aespa
# # 95 | ETA - NewJeans
# # 96 | 비의 랩소디 - 임재현
# # 97 | Poet | Artist - SHINee (샤이니)
# # 98 | Igloo - KISS OF LIFE
# # 99 | 사건의 지평선 - 윤하(Younha/ユンナ)
# #100 | 뱁새 - 이무진
